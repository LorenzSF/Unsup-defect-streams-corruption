# %% [markdown]
# # Example Notebook
#
# This notebook demonstrates how to use the `python_project_template` package from `src/`.
#
# Run the code cell below to see the `summarize` function in action.

# %%
from pathlib import Path
import sys

# Make the src/ package importable from the notebook (adjust path if needed)
sys.path.insert(0, str(Path("..") / "src"))
from python_project_template.core import summarize

data = [1.0, 2.5, 3.75]
print("data =", data)
print("summary =", summarize(data))
# Out:
# data = [1.0, 2.5, 3.75]
# summary = {'count': 3, 'mean': 2.4166666666666665}
